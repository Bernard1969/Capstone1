# %% [markdown]
# # Proposal for New Office Location for Toronto Business Coders

# %% [markdown]
# We are starting a consulting business for data science services and java development services in Toronto, and looking to open an office with a start-up theme.  The target is to find the best location for the office, in order to maximize productivity return on employee selection, with the leading thought being that proximity to coffee shops impacts productivity.  I propose to find support for that idea, against apartment rental costs, and then to locate candidate neighborhoods accordingly.

# %% [markdown]
# The data we use to support this inquiry are: Foursquare location data for Toronto neighborhoods and coffee businesses; Toronto apartment pricing data from
# https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods.

# %% [markdown]
# # Import libraries

# %%
import requests 
import pandas as pd 
import numpy as np 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from bs4 import BeautifulSoup
import json

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
import xml
from sklearn.cluster import KMeans

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# # Toronto neighborhood demographics (wikipedia to dataframe)

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
table = soup.find('tbody')
rows = table.select('tr')
row = [r.get_text() for r in rows]

# %%
df = pd.DataFrame(row)
df1 = df[0].str.split('\n', expand=True)
df2 = df1.rename(columns=df1.iloc[0])
df3 = df2.drop(df2.index[0])
df4 = df3[df3.Borough != 'Not assigned']
df5 = df4.groupby(['Postcode', 'Borough'], sort = False).agg(','.join)
df5.reset_index(inplace = True)
df6 = df5.replace("Not assigned", "Queen's Park")
df6.head()
# Out:
#   Postcode           Borough                    Neighbourhood
# 0      M3A        North York                        Parkwoods
# 1      M4A        North York                 Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront,Regent Park
# 3      M6A        North York  Lawrence Heights,Lawrence Manor
# 4      M7A      Queen's Park                     Queen's Park

# %% [markdown]
# # Foursquare details

# %%
ClIENT_ID = 'A33R5RDKUNUOOIVEHZ1HS2NKGGJRXDOT13KCLQKHV3UFVD4K' # Foursquare ID
ClIENT_SECRET = 'PE1JSVLQQCNSL54HFFMDJWVUROHXDVY2IJHXMMAZ4JPSGILF' # Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: A33R5RDKUNUOOIVEHZ1HS2NKGGJRXDOT13KCLQKHV3UFVD4K
# Foursquare_Secret:PE1JSVLQQCNSL54HFFMDJWVUROHXDVY2IJHXMMAZ4JPSGILF

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# # Find Coffee Shops

# %%
search_query = 'Coffee'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A33R5RDKUNUOOIVEHZ1HS2NKGGJRXDOT13KCLQKHV3UFVD4K&client_secret=PE1JSVLQQCNSL54HFFMDJWVUROHXDVY2IJHXMMAZ4JPSGILF&ll=43.653963,-79.387207&v=20180604&query=Coffee&radius=500&limit=30'

# %%
search_query2 = 'Cafe'
radius = 500

# Define the corresponding URL
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query2, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=A33R5RDKUNUOOIVEHZ1HS2NKGGJRXDOT13KCLQKHV3UFVD4K&client_secret=PE1JSVLQQCNSL54HFFMDJWVUROHXDVY2IJHXMMAZ4JPSGILF&ll=43.653963,-79.387207&v=20180604&query=Cafe&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url2).json()

# %%
# assign relevant part of JSON to coffee shops
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 1   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 2   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 3   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 4   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 5   [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 6   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 7   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 8   [{'id': '4bf58dd8d48988d148941735', 'name': 'D...    False
# 9   [{'id': '4bf58dd8d48988d123951735', 'name': 'S...    False
# 10  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 11  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 12  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 13  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 14  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 15  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 16  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 17  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 18  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...    False
# 19  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 20  [{'id': '4bf58dd8d48988d119941735', 'name': 'H...    False
# 21  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 22  [{'id': '4bf58dd8d48988d1c0941735', 'name': 'M...    False
# 23  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 24  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 25  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 26  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 27  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 28                                                 []    False
# 29  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
#
#                           id        location.address location.cc  \
# 0   4b0d2ef1f964a520664423e3      480 University Ave          CA
# 1   52306d48498e7f7573f576fa      225 Richmond St. W          CA
# 2   4f513029e4b07c3382c9fdb9  250 Dundas Street West          CA
# 3   58e716e5fa7ed04f61194722         201 Dundas St W          CA
# 4   4ad4c060f964a52064f720e3     317 Dundas Street W          CA
# 5   4ab989ebf964a520cc7f20e3         208 Queen St. W          CA
# 6   4aec87eff964a52058c821e3          24 Baldwin St.          CA
# 7   5ab82b0d62420b32095c8ff1  201 Dundas Street West          CA
# 8   4e5cecc9fa76a4cf148bc565          162 McCaul St.          CA
# 9   5241f2d911d26e5c0417c933         205 Dundas St W          CA
# 10  51bd60fa498e5ce3f52c6016         442 Dundas St W          CA
# 11  5655f6ca498ec7cc096eb46d       193 Church Street          CA
# 12  51b3697a498ecbc1c99a64f7                     NaN          CA
# 13  4ae47067f964a520989a21e3      334 Dundas St West          CA
# 14  5750c05e498ed2dde680c9b7       23 Baldwin Street          CA
# 15  5706b570498e618216dbfd32     191 Dundas St. West          CA
# 16  4cd9a6d5a423a35d6415f242                     NaN          CA
# 17  4e2964c1636585a51e9c5ffc      555 University Ave          CA
# 18  5a7f4b625c6838017f986795       111 Richmond St W          CA
# 19  50004b57e4b0033fee2a0f83                     NaN          CA
# 20  59434a134c954c4ff5b009a5           112 Dundas St          CA
# 21  59dfabbac0cacb6488bd4518                     NaN          CA
# 22  5306459111d2e522113082d1          650 Bay Street          CA
# 23  57462ae4498efddb24245014              595 Bay St          CA
# 24  4b06ef4cf964a52072f322e3          100 Queen St W          CA
# 25  4e42c2c2ae60a296fae91bae        100 King St West          CA
# 26  4ba9507af964a520051e3ae3                     NaN          CA
# 27  4d13ac41e3508eec6ebcdd38             610 Bay St.          CA
# 28  4b772923f964a5208f832ee3                     NaN          CA
# 29  51dee270498e110b01d89d6f                     NaN          CA
#
#    location.city location.country    location.crossStreet  location.distance  \
# 0        Toronto           Canada          at Dundas St W                179
# 1        Toronto           Canada           at Duncan St.                541
# 2        Toronto           Canada           Simcoe Street                192
# 3        Toronto           Canada                     NaN                102
# 4        Toronto           Canada                     NaN                347
# 5        Toronto           Canada                     NaN                426
# 6        Toronto           Canada             at Henry St                553
# 7        Toronto           Canada                     NaN                 99
# 8        Toronto           Canada   btwn D'Arcy & Baldwin                434
# 9        Toronto           Canada                     NaN                 98
# 10       Toronto           Canada                     NaN                106
# 11       Toronto           Canada                  Dundas                574
# 12           NaN           Canada                     NaN                262
# 13       Toronto           Canada                     NaN                430
# 14       Toronto           Canada  btwn Henry & McCaul St                523
# 15       Toronto           Canada          At Centre Ave.                118
# 16           NaN           Canada                     NaN                218
# 17       Toronto           Canada                     NaN                397
# 18       Toronto           Canada                     NaN                494
# 19       Toronto           Canada                     NaN                277
# 20       Toronto           Canada                     NaN                305
# 21       Toronto           Canada                     NaN                342
# 22       Toronto           Canada              Elm Street                405
# 23       Toronto           Canada          Dundas St West                407
# 24       Toronto           Canada                     NaN                343
# 25       Toronto           Canada                     Bay                417
# 26           NaN           Canada                     NaN                372
# 27       Toronto           Canada                     NaN                422
# 28           NaN           Canada                     NaN                460
# 29           NaN           Canada                     NaN                471
#
#                             location.formattedAddress  \
# 0   [480 University Ave (at Dundas St W), Toronto ...
# 1   [225 Richmond St. W (at Duncan St.), Toronto O...
# 2   [250 Dundas Street West (Simcoe Street), Toron...
# 3       [201 Dundas St W, Toronto ON M5G 1C8, Canada]
# 4   [317 Dundas Street W, Toronto ON M5T 1G4, Canada]
# 5       [208 Queen St. W, Toronto ON M5V 1Z2, Canada]
# 6   [24 Baldwin St. (at Henry St), Toronto ON M5T ...
# 7   [201 Dundas Street West, Toronto ON M5G 1C8, C...
# 8   [162 McCaul St. (btwn D'Arcy & Baldwin), Toron...
# 9       [205 Dundas St W, Toronto ON M5G 1Z8, Canada]
# 10              [442 Dundas St W, Toronto ON, Canada]
# 11   [193 Church Street (Dundas), Toronto ON, Canada]
# 12                                           [Canada]
# 13   [334 Dundas St West, Toronto ON M5T 1G5, Canada]
# 14  [23 Baldwin Street (btwn Henry & McCaul St), T...
# 15  [191 Dundas St. West (At Centre Ave.), Toronto...
# 16                                           [Canada]
# 17   [555 University Ave, Toronto ON M5V 1X8, Canada]
# 18    [111 Richmond St W, Toronto ON M5H 2G4, Canada]
# 19                               [Toronto ON, Canada]
# 20        [112 Dundas St, Toronto ON M5G 1C3, Canada]
# 21                       [Toronto ON M5T 2W7, Canada]
# 22  [650 Bay Street (Elm Street), Toronto ON M5G 1...
# 23  [595 Bay St (Dundas St West), Toronto ON, Canada]
# 24       [100 Queen St W, Toronto ON M5H 2N2, Canada]
# 25  [100 King St West (Bay), Toronto ON M5X 1 K7, ...
# 26                                           [Canada]
# 27                  [610 Bay St., Toronto ON, Canada]
# 28                                           [Canada]
# 29                                           [Canada]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 43.65511700442771...     43.655117
# 1   [{'label': 'display', 'lat': 43.64934659382636...     43.649347
# 2   [{'label': 'display', 'lat': 43.65457125894357...     43.654571
# 3   [{'label': 'display', 'lat': 43.654872, 'lng':...     43.654872
# 4   [{'label': 'display', 'lat': 43.65405398907735...     43.654054
# 5   [{'label': 'display', 'lat': 43.650401, 'lng':...     43.650401
# 6   [{'label': 'display', 'lat': 43.65621134762937...     43.656211
# 7   [{'label': 'display', 'lat': 43.65485, 'lng': ...     43.654850
# 8   [{'label': 'display', 'lat': 43.65577205054815...     43.655772
# 9   [{'label': 'display', 'lat': 43.65484729461433...     43.654847
# 10  [{'label': 'display', 'lat': 43.654916, 'lng':...     43.654916
# 11  [{'label': 'display', 'lat': 43.65608780148982...     43.656088
# 12  [{'label': 'display', 'lat': 43.65605578874265...     43.656056
# 13  [{'label': 'display', 'lat': 43.65422714439051...     43.654227
# 14  [{'label': 'display', 'lat': 43.65607098189164...     43.656071
# 15  [{'label': 'display', 'lat': 43.65500131144402...     43.655001
# 16  [{'label': 'display', 'lat': 43.65513432222222...     43.655134
# 17  [{'label': 'display', 'lat': 43.65747769310558...     43.657478
# 18  [{'label': 'display', 'lat': 43.650295, 'lng':...     43.650295
# 19  [{'label': 'display', 'lat': 43.6525764465332,...     43.652576
# 20  [{'label': 'display', 'lat': 43.655693, 'lng':...     43.655693
# 21  [{'label': 'display', 'lat': 43.653584, 'lng':...     43.653584
# 22  [{'label': 'display', 'lat': 43.6569522025825,...     43.656952
# 23  [{'label': 'display', 'lat': 43.656204, 'lng':...     43.656204
# 24  [{'label': 'display', 'lat': 43.65263298456729...     43.652633
# 25  [{'label': 'display', 'lat': 43.65109, 'lng': ...     43.651090
# 26  [{'label': 'display', 'lat': 43.65633746005019...     43.656337
# 27  [{'label': 'display', 'lat': 43.65708761939393...     43.657088
# 28  [{'label': 'display', 'lat': 43.653887, 'lng':...     43.653887
# 29  [{'label': 'display', 'lat': 43.657339, 'lng':...     43.657339
#
#     location.lng location.postalCode location.state  \
# 0     -79.388764             M5G 1V2             ON
# 1     -79.389338             M5V 2C5             ON
# 2     -79.389450             M5T 2Z5             ON
# 3     -79.387429             M5G 1C8             ON
# 4     -79.391525             M5T 1G4             ON
# 5     -79.389156             M5V 1Z2             ON
# 6     -79.393331             M5T 1L2             ON
# 7     -79.387330             M5G 1C8             ON
# 8     -79.391993             M5T 1W3             ON
# 9     -79.387198             M5G 1Z8             ON
# 10    -79.387351                 NaN             ON
# 11    -79.380705                 NaN             ON
# 12    -79.385708                 NaN            NaN
# 13    -79.392536             M5T 1G5             ON
# 14    -79.393021             M5T 1L1             ON
# 15    -79.386899                 NaN             ON
# 16    -79.389384                 NaN            NaN
# 17    -79.386360             M5V 1X8             ON
# 18    -79.383750             M5H 2G4             ON
# 19    -79.390068                 NaN             ON
# 20    -79.384267             M5G 1C3             ON
# 21    -79.391430             M5T 2W7             ON
# 22    -79.384328             M5G 1M8             ON
# 23    -79.383210                 NaN             ON
# 24    -79.383361             M5H 2N2             ON
# 25    -79.383880            M5X 1 K7             ON
# 26    -79.383954                 NaN            NaN
# 27    -79.384218                 NaN             ON
# 28    -79.392929                 NaN            NaN
# 29    -79.390749                 NaN            NaN
#
#                                  name    referralId
# 0                Avenue Café + Bistro  v-1564848070
# 1                      The Fifth Cafe  v-1564848070
# 2                         Cafe Plenty  v-1564848070
# 3     Café De Paris, Downtown Toronto  v-1564848070
# 4                             CafeAGO  v-1564848070
# 5                   Queen Mother Cafe  v-1564848070
# 6                       Cafe La Gaffe  v-1564848070
# 7                       One Pear Cafe  v-1564848070
# 8          Krispy Kreme Doughnut Cafe  v-1564848070
# 9              The Prince Shisha Cafe  v-1564848070
# 10                        Prince Cafe  v-1564848070
# 11                  Cafe de Melbourne  v-1564848070
# 12                        Cafe Bistro  v-1564848070
# 13          Art Square Gallery & Cafe  v-1564848070
# 14                    Light Café 路燈咖啡  v-1564848070
# 15  Uncle Tetsu's Japanese Angel Cafe  v-1564848070
# 16                    480 Avenus Cafe  v-1564848070
# 17                   The Terrace Cafe  v-1564848070
# 18                      Hibiscus Cafe  v-1564848070
# 19                       Aramark cafe  v-1564848070
# 20                    King Sisha Cafe  v-1564848070
# 21                     Ascarafed Cafe  v-1564848070
# 22                    650 Cafe Bistro  v-1564848070
# 23        Paris Croissant Bakery Cafe  v-1564848070
# 24                 Cafe On The Square  v-1564848070
# 25                         Oasis Café  v-1564848070
# 26                      Fabulous Cafe  v-1564848070
# 27      Kramden's Café (Bus Terminal)  v-1564848070
# 28                      Espresso Cafe  v-1564848070
# 29                    On The Way Cafe  v-1564848070

# %% [markdown]
# # Clean dataframe

# %%
df1 = dataframe
clean_columns = ['name', 'categories'] + [col for col in df1.columns if col.startswith('location.')]+ ['id']
clean_dataframe = df1.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                               name      categories                 address  \
# 0             Avenue Café + Bistro  Sandwich Place      480 University Ave
# 1                   The Fifth Cafe            Café      225 Richmond St. W
# 2                      Cafe Plenty            Café  250 Dundas Street West
# 3  Café De Paris, Downtown Toronto            Café         201 Dundas St W
# 4                          CafeAGO            Café     317 Dundas Street W
#
#    cc     city country     crossStreet  distance  \
# 0  CA  Toronto  Canada  at Dundas St W       179
# 1  CA  Toronto  Canada   at Duncan St.       541
# 2  CA  Toronto  Canada   Simcoe Street       192
# 3  CA  Toronto  Canada             NaN       102
# 4  CA  Toronto  Canada             NaN       347
#
#                                     formattedAddress  \
# 0  [480 University Ave (at Dundas St W), Toronto ...
# 1  [225 Richmond St. W (at Duncan St.), Toronto O...
# 2  [250 Dundas Street West (Simcoe Street), Toron...
# 3      [201 Dundas St W, Toronto ON M5G 1C8, Canada]
# 4  [317 Dundas Street W, Toronto ON M5T 1G4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65511700442771...  43.655117 -79.388764
# 1  [{'label': 'display', 'lat': 43.64934659382636...  43.649347 -79.389338
# 2  [{'label': 'display', 'lat': 43.65457125894357...  43.654571 -79.389450
# 3  [{'label': 'display', 'lat': 43.654872, 'lng':...  43.654872 -79.387429
# 4  [{'label': 'display', 'lat': 43.65405398907735...  43.654054 -79.391525
#
#   postalCode state                        id
# 0    M5G 1V2    ON  4b0d2ef1f964a520664423e3
# 1    M5V 2C5    ON  52306d48498e7f7573f576fa
# 2    M5T 2Z5    ON  4f513029e4b07c3382c9fdb9
# 3    M5G 1C8    ON  58e716e5fa7ed04f61194722
# 4    M5T 1G4    ON  4ad4c060f964a52064f720e3

# %%
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress', 'id'], axis=1)
clean_dataframe2
# Out:
#                                  name                     categories  \
# 0                Avenue Café + Bistro                 Sandwich Place
# 1                      The Fifth Cafe                           Café
# 2                         Cafe Plenty                           Café
# 3     Café De Paris, Downtown Toronto                           Café
# 4                             CafeAGO                           Café
# 5                   Queen Mother Cafe                Thai Restaurant
# 6                       Cafe La Gaffe                           Café
# 7                       One Pear Cafe           Fast Food Restaurant
# 8          Krispy Kreme Doughnut Cafe                     Donut Shop
# 9              The Prince Shisha Cafe                     Smoke Shop
# 10                        Prince Cafe                           Café
# 11                  Cafe de Melbourne                           Café
# 12                        Cafe Bistro                           Café
# 13          Art Square Gallery & Cafe                    Art Gallery
# 14                    Light Café 路燈咖啡                           Café
# 15  Uncle Tetsu's Japanese Angel Cafe                           Café
# 16                    480 Avenus Cafe                           Café
# 17                   The Terrace Cafe                           Café
# 18                      Hibiscus Cafe  Vegetarian / Vegan Restaurant
# 19                       Aramark cafe                     Food Court
# 20                    King Sisha Cafe                     Hookah Bar
# 21                     Ascarafed Cafe                    Coffee Shop
# 22                    650 Cafe Bistro       Mediterranean Restaurant
# 23        Paris Croissant Bakery Cafe                         Bakery
# 24                 Cafe On The Square                     Restaurant
# 25                         Oasis Café                           Café
# 26                      Fabulous Cafe                            Bar
# 27      Kramden's Café (Bus Terminal)                           Café
# 28                      Espresso Cafe                           None
# 29                    On The Way Cafe                         Bakery
#
#                    address                                     labeledLatLngs  \
# 0       480 University Ave  [{'label': 'display', 'lat': 43.65511700442771...
# 1       225 Richmond St. W  [{'label': 'display', 'lat': 43.64934659382636...
# 2   250 Dundas Street West  [{'label': 'display', 'lat': 43.65457125894357...
# 3          201 Dundas St W  [{'label': 'display', 'lat': 43.654872, 'lng':...
# 4      317 Dundas Street W  [{'label': 'display', 'lat': 43.65405398907735...
# 5          208 Queen St. W  [{'label': 'display', 'lat': 43.650401, 'lng':...
# 6           24 Baldwin St.  [{'label': 'display', 'lat': 43.65621134762937...
# 7   201 Dundas Street West  [{'label': 'display', 'lat': 43.65485, 'lng': ...
# 8           162 McCaul St.  [{'label': 'display', 'lat': 43.65577205054815...
# 9          205 Dundas St W  [{'label': 'display', 'lat': 43.65484729461433...
# 10         442 Dundas St W  [{'label': 'display', 'lat': 43.654916, 'lng':...
# 11       193 Church Street  [{'label': 'display', 'lat': 43.65608780148982...
# 12                     NaN  [{'label': 'display', 'lat': 43.65605578874265...
# 13      334 Dundas St West  [{'label': 'display', 'lat': 43.65422714439051...
# 14       23 Baldwin Street  [{'label': 'display', 'lat': 43.65607098189164...
# 15     191 Dundas St. West  [{'label': 'display', 'lat': 43.65500131144402...
# 16                     NaN  [{'label': 'display', 'lat': 43.65513432222222...
# 17      555 University Ave  [{'label': 'display', 'lat': 43.65747769310558...
# 18       111 Richmond St W  [{'label': 'display', 'lat': 43.650295, 'lng':...
# 19                     NaN  [{'label': 'display', 'lat': 43.6525764465332,...
# 20           112 Dundas St  [{'label': 'display', 'lat': 43.655693, 'lng':...
# 21                     NaN  [{'label': 'display', 'lat': 43.653584, 'lng':...
# 22          650 Bay Street  [{'label': 'display', 'lat': 43.6569522025825,...
# 23              595 Bay St  [{'label': 'display', 'lat': 43.656204, 'lng':...
# 24          100 Queen St W  [{'label': 'display', 'lat': 43.65263298456729...
# 25        100 King St West  [{'label': 'display', 'lat': 43.65109, 'lng': ...
# 26                     NaN  [{'label': 'display', 'lat': 43.65633746005019...
# 27             610 Bay St.  [{'label': 'display', 'lat': 43.65708761939393...
# 28                     NaN  [{'label': 'display', 'lat': 43.653887, 'lng':...
# 29                     NaN  [{'label': 'display', 'lat': 43.657339, 'lng':...
#
#           lat        lng postalCode state
# 0   43.655117 -79.388764    M5G 1V2    ON
# 1   43.649347 -79.389338    M5V 2C5    ON
# 2   43.654571 -79.389450    M5T 2Z5    ON
# 3   43.654872 -79.387429    M5G 1C8    ON
# 4   43.654054 -79.391525    M5T 1G4    ON
# 5   43.650401 -79.389156    M5V 1Z2    ON
# 6   43.656211 -79.393331    M5T 1L2    ON
# 7   43.654850 -79.387330    M5G 1C8    ON
# 8   43.655772 -79.391993    M5T 1W3    ON
# 9   43.654847 -79.387198    M5G 1Z8    ON
# 10  43.654916 -79.387351        NaN    ON
# 11  43.656088 -79.380705        NaN    ON
# 12  43.656056 -79.385708        NaN   NaN
# 13  43.654227 -79.392536    M5T 1G5    ON
# 14  43.656071 -79.393021    M5T 1L1    ON
# 15  43.655001 -79.386899        NaN    ON
# 16  43.655134 -79.389384        NaN   NaN
# 17  43.657478 -79.386360    M5V 1X8    ON
# 18  43.650295 -79.383750    M5H 2G4    ON
# 19  43.652576 -79.390068        NaN    ON
# 20  43.655693 -79.384267    M5G 1C3    ON
# 21  43.653584 -79.391430    M5T 2W7    ON
# 22  43.656952 -79.384328    M5G 1M8    ON
# 23  43.656204 -79.383210        NaN    ON
# 24  43.652633 -79.383361    M5H 2N2    ON
# 25  43.651090 -79.383880   M5X 1 K7    ON
# 26  43.656337 -79.383954        NaN   NaN
# 27  43.657088 -79.384218        NaN    ON
# 28  43.653887 -79.392929        NaN   NaN
# 29  43.657339 -79.390749        NaN   NaN

# %%
# delete rows which its category is not a cafe
array= ['Café']
cafe_dataframe2 = clean_dataframe.loc[clean_dataframe2['categories'].isin(array)]
cafe_dataframe2
# Out:
#                                  name categories                 address  cc  \
# 1                      The Fifth Cafe       Café      225 Richmond St. W  CA
# 2                         Cafe Plenty       Café  250 Dundas Street West  CA
# 3     Café De Paris, Downtown Toronto       Café         201 Dundas St W  CA
# 4                             CafeAGO       Café     317 Dundas Street W  CA
# 6                       Cafe La Gaffe       Café          24 Baldwin St.  CA
# 10                        Prince Cafe       Café         442 Dundas St W  CA
# 11                  Cafe de Melbourne       Café       193 Church Street  CA
# 12                        Cafe Bistro       Café                     NaN  CA
# 14                    Light Café 路燈咖啡       Café       23 Baldwin Street  CA
# 15  Uncle Tetsu's Japanese Angel Cafe       Café     191 Dundas St. West  CA
# 16                    480 Avenus Cafe       Café                     NaN  CA
# 17                   The Terrace Cafe       Café      555 University Ave  CA
# 25                         Oasis Café       Café        100 King St West  CA
# 27      Kramden's Café (Bus Terminal)       Café             610 Bay St.  CA
#
#        city country             crossStreet  distance  \
# 1   Toronto  Canada           at Duncan St.       541
# 2   Toronto  Canada           Simcoe Street       192
# 3   Toronto  Canada                     NaN       102
# 4   Toronto  Canada                     NaN       347
# 6   Toronto  Canada             at Henry St       553
# 10  Toronto  Canada                     NaN       106
# 11  Toronto  Canada                  Dundas       574
# 12      NaN  Canada                     NaN       262
# 14  Toronto  Canada  btwn Henry & McCaul St       523
# 15  Toronto  Canada          At Centre Ave.       118
# 16      NaN  Canada                     NaN       218
# 17  Toronto  Canada                     NaN       397
# 25  Toronto  Canada                     Bay       417
# 27  Toronto  Canada                     NaN       422
#
#                                      formattedAddress  \
# 1   [225 Richmond St. W (at Duncan St.), Toronto O...
# 2   [250 Dundas Street West (Simcoe Street), Toron...
# 3       [201 Dundas St W, Toronto ON M5G 1C8, Canada]
# 4   [317 Dundas Street W, Toronto ON M5T 1G4, Canada]
# 6   [24 Baldwin St. (at Henry St), Toronto ON M5T ...
# 10              [442 Dundas St W, Toronto ON, Canada]
# 11   [193 Church Street (Dundas), Toronto ON, Canada]
# 12                                           [Canada]
# 14  [23 Baldwin Street (btwn Henry & McCaul St), T...
# 15  [191 Dundas St. West (At Centre Ave.), Toronto...
# 16                                           [Canada]
# 17   [555 University Ave, Toronto ON M5V 1X8, Canada]
# 25  [100 King St West (Bay), Toronto ON M5X 1 K7, ...
# 27                  [610 Bay St., Toronto ON, Canada]
#
#                                        labeledLatLngs        lat        lng  \
# 1   [{'label': 'display', 'lat': 43.64934659382636...  43.649347 -79.389338
# 2   [{'label': 'display', 'lat': 43.65457125894357...  43.654571 -79.389450
# 3   [{'label': 'display', 'lat': 43.654872, 'lng':...  43.654872 -79.387429
# 4   [{'label': 'display', 'lat': 43.65405398907735...  43.654054 -79.391525
# 6   [{'label': 'display', 'lat': 43.65621134762937...  43.656211 -79.393331
# 10  [{'label': 'display', 'lat': 43.654916, 'lng':...  43.654916 -79.387351
# 11  [{'label': 'display', 'lat': 43.65608780148982...  43.656088 -79.380705
# 12  [{'label': 'display', 'lat': 43.65605578874265...  43.656056 -79.385708
# 14  [{'label': 'display', 'lat': 43.65607098189164...  43.656071 -79.393021
# 15  [{'label': 'display', 'lat': 43.65500131144402...  43.655001 -79.386899
# 16  [{'label': 'display', 'lat': 43.65513432222222...  43.655134 -79.389384
# 17  [{'label': 'display', 'lat': 43.65747769310558...  43.657478 -79.386360
# 25  [{'label': 'display', 'lat': 43.65109, 'lng': ...  43.651090 -79.383880
# 27  [{'label': 'display', 'lat': 43.65708761939393...  43.657088 -79.384218
#
#    postalCode state                        id
# 1     M5V 2C5    ON  52306d48498e7f7573f576fa
# 2     M5T 2Z5    ON  4f513029e4b07c3382c9fdb9
# 3     M5G 1C8    ON  58e716e5fa7ed04f61194722
# 4     M5T 1G4    ON  4ad4c060f964a52064f720e3
# 6     M5T 1L2    ON  4aec87eff964a52058c821e3
# 10        NaN    ON  51bd60fa498e5ce3f52c6016
# 11        NaN    ON  5655f6ca498ec7cc096eb46d
# 12        NaN   NaN  51b3697a498ecbc1c99a64f7
# 14    M5T 1L1    ON  5750c05e498ed2dde680c9b7
# 15        NaN    ON  5706b570498e618216dbfd32
# 16        NaN   NaN  4cd9a6d5a423a35d6415f242
# 17    M5V 1X8    ON  4e2964c1636585a51e9c5ffc
# 25   M5X 1 K7    ON  4e42c2c2ae60a296fae91bae
# 27        NaN    ON  4d13ac41e3508eec6ebcdd38

# %%
from math import floor, ceil

latitude = cafe_dataframe2["lat"]
longitude = cafe_dataframe2["lng"]
data_points = [ np.array([i,j]) for i,j in zip(latitude, longitude)]


extension = 0.005
l_min = min(latitude) - extension
l_max = max(latitude) + extension
L_min = min(longitude) - extension
L_max = max(longitude) + extension

l_min, l_max, L_min, L_max
# Out:
# (43.644346593826356, 43.66247769310558, -79.39833144271435, -79.37570487601242)

# %% [markdown]
# # Generate Map

# %%
# Generate map to visualize cafe neighbourhood  
address = 'Toronto'
geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

cafe_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(cafe_dataframe2['lat'], cafe_dataframe2['lng'], 
                                           cafe_dataframe2['name'], cafe_dataframe2['categories'],\
                                               cafe_dataframe2['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(cafe_map)  
    
cafe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
